# %% [markdown]
# <a href="https://colab.research.google.com/github/angieapol33-bot/FUNDAI-Laboratories-APOLINAR/blob/main/CS_FUNDAI_2026_Lab1_APOLINAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 1: Environment Onboarding
#
# ## Fundamentals of Artificial Intelligence
#
# **Name:** Angeline Grace JoY L. Apolinar
# **Course:** BSIT
# **Section:** 2A
# **Date:** 8/19/2026
#
# **GitHub URL:** https://github.com/angieapol33-bot/FUNDAI-Laboratories-APOLINAR.git
#
# ## Description
# This laboratory introduces the use of Google Colab and GitHub for AI laboratory activities. It also implements a simple intelligent agent.

# %%
import sys
import datetime

print("Python version:")
print(sys.version)

print("Current date:")
print(datetime.date.today())
# Out:
# Python version:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Current date:
# 2026-08-18

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

folder_path = "/content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1"
os.makedirs(folder_path, exist_ok=True)

print("Folder ready:", folder_path)
# Out:
# Folder ready: /content/drive/MyDrive/2026/FIRST-SEMESTER/AI-EL_FUNDAI/FUNDAI_Lab1

# %% [markdown]
# ## Simple Intelligent Agent
#
# This simple agent receives a room condition as a percept and produces an action.
#
# The agent follows a condition-action rule:
#
# - If the room is dirty, the agent cleans.
# - If the room is clean, the agent rests.
# - If the room condition is unknown, the agent inspects.

# %%
def simple_reflex_agent(room_condition):
    """
    A simple reflex agent that decides an action based on the room condition.
    """
    room_condition = room_condition.strip().lower()

    if room_condition == "dirty":
        return "CLEAN"
    elif room_condition == "clean":
        return "REST"
    else:
        return "INSPECT"

# %%
percepts = ["dirty", "clean", "dirty", "unknown"]

print("Simple Reflex Agent Test")
print("-" * 30)

for i, percept in enumerate(percepts, start=1):
    action = simple_reflex_agent(percept)
    print(f"Percept {i}: {percept:<8} -> Action: {action}")
# Out:
# Simple Reflex Agent Test
# ------------------------------
# Percept 1: dirty    -> Action: CLEAN
# Percept 2: clean    -> Action: REST
# Percept 3: dirty    -> Action: CLEAN
# Percept 4: unknown  -> Action: INSPECT

# %% [markdown]
# ## Performance Measure
#
# A simple performance measure gives a score when the agent chooses the correct action for the given percept.

# %%
score = 0
total = len(percepts)

for percept in percepts:
    action = simple_reflex_agent(percept)

    if percept == "dirty" and action == "CLEAN":
        score += 1
    elif percept == "clean" and action == "REST":
        score += 1
    elif percept == "unknown" and action == "INSPECT":
        score += 1

print(f"Agent score: {score}/{total}")
# Out:
# Agent score: 4/4

# %% [markdown]
# ## Guide Questions and Answers
#
# ### 1. What is an intelligent agent?
# **Answer:** An intelligent agent is an autonomous entity that processes environmental data via inputs, uses decision-making logic to determine the best response, and executes targeted actions to achieve specific goals.
#
# ### 2. What are the sensors and actuators in this simple agent example?
# **Answer:** The sensor function is fulfilled by reading the room's current state (`room_condition`), while the actuator role is carried out by returning conditional action strings (`CLEAN`, `REST`, or `INSPECT`).
#
# ### 3. Why is documentation important in AI laboratory work?
# **Answer:** Documentation provides a clear audit trail for reproducing experiments, clarifies algorithmic logic for peer review, and helps verify that the AI agent meets its intended performance criteria.

# %% [markdown]
# ## Reflection
#
# ### Challenges Encountered
# - Understanding how to map discrete percepts to explicit conditional actions without relying on complex external libraries.
# - Ensuring string input normalization (`strip().lower()`) so the agent handles unexpected formatting gracefully.
#
# ### What I Learned
# - How simple reflex agents rely entirely on current percepts without maintaining a long-term memory or state history.
# - The importance of measuring performance scores to systematically verify whether an agent is making optimal decisions.
