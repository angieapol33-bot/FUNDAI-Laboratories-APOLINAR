# %% [markdown]
# <a href="https://colab.research.google.com/github/angieapol33-bot/FUNDAI-Laboratories-APOLINAR/blob/main/Lab4_Logic_KR_APOLINAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4: Logic and Knowledge Representation
#
# ## Fundamentals of Artificial Intelligence
#
# **Name:** ANGELINE GRACE JOY L APOLINAR
# **Course:** BSIT
# **Section:** 09282-FUNDAI
# **Date:** 9/15/2026
#
# **GitHub URL:** https://github.com/angieapol33-bot/FUNDAI-Laboratories-APOLINAR.git

# %%
from sympy import symbols, And, Or, Not, Implies, Equivalent, satisfiable
from itertools import product

P, Q, R = symbols('P Q R')

def print_truth_table(expression, symbol_list):
    header = [str(s) for s in symbol_list] + [str(expression)]
    print(" | ".join(header))
    print("-" * (5 * len(header)))

    for values in product([False, True], repeat=len(symbol_list)):
        mapping = dict(zip(symbol_list, values))
        result = bool(expression.subs(mapping))
        row = [str(v) for v in values] + [str(result)]
        print(" | ".join(row))

    print()

    print("Negation: NOT P")
print_truth_table(Not(P), [P])

print("Conjunction: P AND Q")
print_truth_table(And(P, Q), [P, Q])

print("Disjunction: P OR Q")
print_truth_table(Or(P, Q), [P, Q])

print("Implication: P -> Q")
print_truth_table(Implies(P, Q), [P, Q])

print("Biconditional: P <-> Q")
print_truth_table(Equivalent(P, Q), [P, Q])
# Out:
# P | ~P
# ----------
# False | True
# True | False
#
# Negation: NOT P
# Conjunction: P AND Q
# P | Q | P & Q
# ---------------
# False | False | False
# False | True | False
# True | False | False
# True | True | True
#
# Negation: NOT P
# Disjunction: P OR Q
# P | Q | P | Q
# ---------------
# False | False | False
# False | True | True
# True | False | True
# True | True | True
#
# Negation: NOT P
# Implication: P -> Q
# P | Q | Implies(P, Q)
# ---------------
# False | False | True
# False | True | True
# True | False | False
# True | True | True
#
# Negation: NOT P
# Biconditional: P <-> Q
# P | Q | Equivalent(P, Q)
# ---------------
# False | False | True
# False | True | False
# True | False | False
# True | True | True
#
# Negation: NOT P

# %%
def is_tautology(expression, symbol_list):
    for values in product([False, True], repeat=len(symbol_list)):
        mapping = dict(zip(symbol_list, values))
        if not bool(expression.subs(mapping)):
            return False
    return True

    law_of_excluded_middle = Or(P, Not(P))
contradiction = And(P, Not(P))
simple_implication = Implies(P, Q)

# %%
law_of_excluded_middle = Or(P, Not(P))
contradiction = And(P, Not(P))
simple_implication = Implies(P, Q)

print("P OR NOT P is a tautology:", is_tautology(law_of_excluded_middle, [P]))
print("P AND NOT P is a tautology:", is_tautology(contradiction, [P]))
print("P -> Q is a tautology:", is_tautology(simple_implication, [P, Q]))
# Out:
# P OR NOT P is a tautology: True
# P AND NOT P is a tautology: False
# P -> Q is a tautology: False

# %%
def is_satisfiable(expression):
    return satisfiable(expression) is not False

print("P AND NOT P is satisfiable:", is_satisfiable(And(P, Not(P))))
print("P OR Q is satisfiable:", is_satisfiable(Or(P, Q)))
print("P -> Q is satisfiable:", is_satisfiable(Implies(P, Q)))
# Out:
# P AND NOT P is satisfiable: False
# P OR Q is satisfiable: True
# P -> Q is satisfiable: True

# %%
def to_conjunction(kb):
    if isinstance(kb, list):
        return And(*kb)
    return kb

# %%
def kb_entails(kb, conclusion):
    kb_expression = to_conjunction(kb)
    counter_check = And(kb_expression, Not(conclusion))
    return satisfiable(counter_check) is False

# %%
def check_entailment(kb, conclusion, label="Query"):
    holds = kb_entails(kb, conclusion)
    kb_expression = to_conjunction(kb)
    counterexample = satisfiable(And(kb_expression, Not(conclusion)))

    print(label)

    if holds:
        print("Result: Entailment holds.")
    else:
        print("Result: Entailment does not hold.")
        print("Counterexample model:", counterexample)

    print("-" * 60)
    return holds

# %%
Rain, Wet = symbols('Rain Wet')

kb_rain = [
    Implies(Rain, Wet),
    Rain
]

check_entailment(kb_rain, Wet, "Theorem Proving: Rain example")
# Out:
# Theorem Proving: Rain example
# Result: Entailment holds.
# ------------------------------------------------------------
# True

# %%
kb_invalid = [
    Implies(Rain, Wet),
    Wet
]

check_entailment(kb_invalid, Rain, "Invalid Inference: Affirming the consequent")
# Out:
# Invalid Inference: Affirming the consequent
# Result: Entailment does not hold.
# Counterexample model: {Wet: True, Rain: False}
# ------------------------------------------------------------
# False

# %%
print("Logical Deduction Rules")
print("=" * 60)

# Modus Ponens
check_entailment(
    [P, Implies(P, Q)],
    Q,
    "Modus Ponens: P, P -> Q, therefore Q"
)

# Modus Tollens
check_entailment(
    [Not(Q), Implies(P, Q)],
    Not(P),
    "Modus Tollens: NOT Q, P -> Q, therefore NOT P"
)
# Out:
# Logical Deduction Rules
# ============================================================
# Modus Ponens: P, P -> Q, therefore Q
# Result: Entailment holds.
# ------------------------------------------------------------
# Modus Tollens: NOT Q, P -> Q, therefore NOT P
# Result: Entailment holds.
# ------------------------------------------------------------
# True

# %% [markdown]
# ## Grounded First-Order Logic Example
#
# Full First-Order Logic includes objects and quantifiers.
# For this laboratory, we demonstrate a simple grounded FOL example
# by converting FOL atoms into propositional symbols.
#
# English:
# - All humans are mortal.
# - Socrates is human.
# - Therefore, Socrates is mortal.
#
# Grounded propositional form:
# - Human_Socrates -> Mortal_Socrates

# %%
Human_Socrates, Mortal_Socrates = symbols('Human_Socrates Mortal_Socrates')

kb_socrates = [
    Implies(Human_Socrates, Mortal_Socrates),
    Human_Socrates
]

check_entailment(
    kb_socrates,
    Mortal_Socrates,
    "Grounded FOL: Socrates is mortal"
)
# Out:
# Grounded FOL: Socrates is mortal
# Result: Entailment holds.
# ------------------------------------------------------------
# True

# %%
def make_human_mortal_kb(constants):
    kb = []
    human = {}
    mortal = {}

    for name in constants:
        h, m = symbols(f'Human_{name} Mortal_{name}')
        human[name] = h
        mortal[name] = m
        kb.append(Implies(h, m))

    return kb, human, mortal

# %%
constants = ["Socrates", "Plato"]

kb_people, human, mortal = make_human_mortal_kb(constants)

# Add facts
kb_people.append(human["Socrates"])
kb_people.append(human["Plato"])

# Query: Is Plato mortal?
check_entailment(
    kb_people,
    mortal["Plato"],
    "Grounded FOL with multiple constants: Is Plato mortal?"
)
# Out:
# Grounded FOL with multiple constants: Is Plato mortal?
# Result: Entailment holds.
# ------------------------------------------------------------
# True

# %% [markdown]
# ## Guide Questions and Answers
#
# ### 1. What is the difference between syntax and semantics?
# **Answer:** Syntax defines the structure and grammatical rules for building valid logical expressions (e.g., ensuring symbols like `P`, `Q`, and `Implies` are formatted correctly). Semantics refers to the actual meaning or truth value assigned to those expressions in a specific context—determining whether a statement evaluates to True or False.
#
# ### 2. Why is `P -> Q` true when `P` is false?
# **Answer:** In formal logic, conditional statements ($P \implies Q$) are vacuously true when the premise ($P$) is false. Because the premise did not occur, the implication was never violated or proven wrong, regardless of whether $Q$ happens to be true or false.
#
# ### 3. What does it mean for a knowledge base to entail a conclusion?
# **Answer:** A knowledge base ($KB$) entails a conclusion ($\alpha$) if the conclusion is logically guaranteed to be true in every possible scenario or world where all statements in the $KB$ are true. In short, $KB \models \alpha$ means there is no state of the world where the $KB$ holds true while the conclusion is false.
#
# ### 4. How does theorem proving use satisfiability checking?
# **Answer:** Theorem proving uses satisfiability checking through refutation (proof by contradiction). To prove that $KB$ entails $\alpha$, we check if the combination of the knowledge base and the negated conclusion ($KB \land \neg \alpha$) is satisfiable. If $KB \land \neg \alpha$ is unsatisfiable (returns False), it proves that a counterexample cannot exist, thereby confirming that the entailment holds.
#
# ### 5. What is one limitation of propositional logic compared to First-Order Logic?
# **Answer:** Propositional logic lacks fine-grained expressiveness because it treats every statement as a monolithic atomic proposition. It cannot explicitly quantify over groups or represent relationships between specific objects and properties (such as "For all $x$, if $x$ is Human then $x$ is Mortal") without explicitly defining a separate propositional variable for every single object in the domain.

# %% [markdown]
# ## Reflection
#
# ### Challenges Encountered
# - Mapping logical concepts like $KB \models \alpha$ into Python code initially required careful thinking, especially understanding how `satisfiable(And(KB, Not(conclusion)))` acts as a counterexample finder.
# - Managing symbol mappings correctly using SymPy dictionary lookups required attention to syntax when working with dynamic lists in Python.
#
# ### What I Learned
# - Learned how to programmatically construct truth tables and verify logical properties like tautology and satisfiability using Python libraries like `sympy` and `itertools`.
# - Gained a solid computational understanding of logical deduction rules (such as Modus Ponens and Modus Tollens) and how automated reasoning tools perform entailment checks through satisfiability testing.
